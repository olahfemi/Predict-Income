# %%
import pandas as pd
import keras
import numpy as np
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.
# C:\ProgramData\Miniconda3\envs\minimal_ds\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\ProgramData\Miniconda3\envs\minimal_ds\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\ProgramData\Miniconda3\envs\minimal_ds\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
df = pd.read_csv('donor_dataset.csv', index_col = False)

# %%
df.head()
# Out:
#    Unnamed: 0       age  education-num  capital-gain  capital-loss  \
# 0           0  0.301370       0.800000      0.667492           0.0
# 1           1  0.452055       0.800000      0.000000           0.0
# 2           2  0.287671       0.533333      0.000000           0.0
# 3           3  0.493151       0.400000      0.000000           0.0
# 4           4  0.150685       0.800000      0.000000           0.0
#
#    hours-per-week  workclass_ Federal-gov  workclass_ Local-gov  \
# 0        0.397959                       0                     0
# 1        0.122449                       0                     0
# 2        0.397959                       0                     0
# 3        0.397959                       0                     0
# 4        0.397959                       0                     0
#
#    workclass_ Private  workclass_ Self-emp-inc  ...  \
# 0                   0                        0  ...
# 1                   0                        0  ...
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45222 entries, 0 to 45221
# Columns: 104 entries, age to income
# dtypes: float64(5), int64(99)
# memory usage: 35.9 MB

# %%
X = df.drop('income', axis = 1)

# %%
df.head()
# Out:
#         age  education-num  capital-gain  capital-loss  hours-per-week  \
# 0  0.301370       0.800000      0.667492           0.0        0.397959
# 1  0.452055       0.800000      0.000000           0.0        0.122449
# 2  0.287671       0.533333      0.000000           0.0        0.397959
# 3  0.493151       0.400000      0.000000           0.0        0.397959
# 4  0.150685       0.800000      0.000000           0.0        0.397959
#
#    workclass_ Federal-gov  workclass_ Local-gov  workclass_ Private  \
# 0                       0                     0                   0
# 1                       0                     0                   0
# 2                       0                     0                   1
# 3                       0                     0                   1
# 4                       0                     0                   1
#
#    workclass_ Self-emp-inc  workclass_ Self-emp-not-inc  ...  \
# 0                        0                            0  ...
# ...

# %%
y = df[['income']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
l0 = keras.layers.Dense(units = 12, activation='sigmoid', input_shape = [103])
l1 = keras.layers.Dense(units = 12, activation='sigmoid')
l2 = keras.layers.Dense(units = 1, activation = 'sigmoid')

# %%
# Stack the layers
model = keras.Sequential([l0, l1, l2])
# Out:
# WARNING:tensorflow:From C:\ProgramData\Miniconda3\envs\minimal_ds\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Configure the model for training
model.compile(loss = 'binary_crossentropy',
              optimizer = keras.optimizers.Adam(0.1), metrics = ['accuracy'])

# %%
# Train the model
model.fit(x = X_train, y = y_train, validation_data = (X_test, y_test), epochs = 10)
print('Model Trained')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Miniconda3\envs\minimal_ds\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 31655 samples, validate on 13567 samples
# Epoch 1/10
# 31655/31655 [==============================] - 2s 74us/step - loss: 0.3703 - acc: 0.8263 - val_loss: 0.3542 - val_acc: 0.8370
# Epoch 2/10
# 31655/31655 [==============================] - 2s 58us/step - loss: 0.3553 - acc: 0.8337 - val_loss: 0.3497 - val_acc: 0.8357
# Epoch 3/10
# 31655/31655 [==============================] - 2s 58us/step - loss: 0.3531 - acc: 0.8346 - val_loss: 0.3549 - val_acc: 0.8381
# Epoch 4/10
# 31655/31655 [==============================] - 2s 58us/step - loss: 0.3530 - acc: 0.8326 - val_loss: 0.3526 - val_acc: 0.8309
# Epoch 5/10
# ...
